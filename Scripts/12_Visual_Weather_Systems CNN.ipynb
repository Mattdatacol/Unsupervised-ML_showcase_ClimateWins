# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Input
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv1D, Conv2D, Dense, BatchNormalization, Flatten, MaxPooling2D, Activation
from keras.layers import Dense, Dropout
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
#download the weather images and put them in a directory
path = r"C:\Users\dacol\Downloads\archive (2)\Multi-class Weather Dataset"
folders = os.listdir(path)
print(folders)
# Out:
# ['Cloudy', 'Rain', 'Shine', 'Sunrise']

# %%
#this will load in the pictures and rescale them to 250x250pixels

datagenerator = ImageDataGenerator(rescale=1/255, validation_split=0.2)
train_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='training',
)

test_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='validation',
)
# Out:
# Found 901 images belonging to 4 classes.
# Found 224 images belonging to 4 classes.

# %%
#this is a CNN to categorize the weather images

inputs = Input(shape=(250, 250, 3))

x = Conv2D(32, (5,5), activation = 'relu')(inputs)
x = MaxPooling2D(3,3)(x)
x = Conv2D(64, (5,5) , activation = 'relu')(x)
x = MaxPooling2D((3,3))(x)
x = Conv2D(128 , (5,5) , activation = 'relu')(x)
x = MaxPooling2D(3,3)(x)
x = Flatten()(x)
x = Dropout(0.5, seed = 5)(x)
x = Dense(128 , activation = 'relu')(x)

outputs = Dense(4, activation = 'softmax')(x)

model:Model = Model(inputs=inputs, outputs=outputs)

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 21, 
    steps_per_epoch = train_generator.n // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size,
)
# Out:
# Epoch 1/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 537ms/step - accuracy: 0.9062 - loss: 0.0383 - val_accuracy: 0.8705 - val_loss: 0.0490
# Epoch 2/21
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 10s 396ms/step - accuracy: 0.8438 - loss: 0.0501
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.8438 - loss: 0.0501 - val_accuracy: 0.8661 - val_loss: 0.0498
# Epoch 3/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 495ms/step - accuracy: 0.9356 - loss: 0.0237 - val_accuracy: 0.8125 - val_loss: 0.0722
# Epoch 4/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8125 - loss: 0.0704 - val_accuracy: 0.8125 - val_loss: 0.0737
# Epoch 5/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 507ms/step - accuracy: 0.9060 - loss: 0.0352 - val_accuracy: 0.8571 - val_loss: 0.0513
# Epoch 6/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9688 - loss: 0.0232 - val_accuracy: 0.8571 - val_loss: 0.0570
# Epoch 7/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 505ms/step - accuracy: 0.9496 - loss: 0.0216 - val_accuracy: 0.8482 - val_loss: 0.0577
# Epoch 8/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9062 - loss: 0.0454 - val_accuracy: 0.8616 - val_loss: 0.0576
# Epoch 9/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 17s 618ms/step - accuracy: 0.9183 - loss: 0.0333 - val_accuracy: 0.8839 - val_loss: 0.0505
# Epoch 10/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8750 - loss: 0.0383 - val_accuracy: 0.8973 - val_loss: 0.0473
# Epoch 11/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 17s 614ms/step - accuracy: 0.9393 - loss: 0.0240 - val_accuracy: 0.8036 - val_loss: 0.0752
# Epoch 12/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9062 - loss: 0.0454 - val_accuracy: 0.7946 - val_loss: 0.0784
# Epoch 13/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 580ms/step - accuracy: 0.8977 - loss: 0.0380 - val_accuracy: 0.8348 - val_loss: 0.0632
# Epoch 14/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9375 - loss: 0.0281 - val_accuracy: 0.8393 - val_loss: 0.0696
# Epoch 15/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 534ms/step - accuracy: 0.9082 - loss: 0.0354 - val_accuracy: 0.8348 - val_loss: 0.0614
# Epoch 16/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8750 - loss: 0.0486 - val_accuracy: 0.8527 - val_loss: 0.0592
# Epoch 17/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 530ms/step - accuracy: 0.9374 - loss: 0.0268 - val_accuracy: 0.8839 - val_loss: 0.0484
# Epoch 18/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.9375 - loss: 0.0218 - val_accuracy: 0.8705 - val_loss: 0.0533
# Epoch 19/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 536ms/step - accuracy: 0.9422 - loss: 0.0223 - val_accuracy: 0.8036 - val_loss: 0.0879
# Epoch 20/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9375 - loss: 0.0349 - val_accuracy: 0.8080 - val_loss: 0.0829
# Epoch 21/21
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 511ms/step - accuracy: 0.9352 - loss: 0.0267 - val_accuracy: 0.8527 - val_loss: 0.0566

# %%
results = pd.DataFrame(model.history.history)

# %%
results[['loss','val_loss']].plot(title='Model Loss')
plt.savefig('./loss.png')

# %%
results[['accuracy','val_accuracy']].plot(title='Model Acurracy')
plt.savefig('./accuracy.png')

# %%
# Print the accuracy and loss
print("Accuracy: {}, Val_Accuracy: {}".format(results['accuracy'].iloc[-1], results['val_accuracy'].iloc[-1]))
print("Loss: {}, Val_Loss: {}".format(results['loss'].iloc[-1], results['val_loss'].iloc[-1]))
# Out:
# Accuracy: 0.9298043847084045, Val_Accuracy: 0.8526785969734192
# Loss: 0.027595462277531624, Val_Loss: 0.05659464746713638

# %%
# collect n batches of images and display the confusion matrix for them.

class_names = ['Cloudy', 'Rain', 'Shine', 'Sunrise']
n = 10 #<--you can change the number of batches selected.

image_batch, classes_batch = next(test_generator)

for batch in range(n):
    temp = next(test_generator)
    image_batch = np.concatenate((image_batch, temp[0]))
    classes_batch = np.concatenate((classes_batch, temp[1]))

classes_batch = classes_batch
y_predict = model.predict(image_batch)

# Confusion matrix for training data
cm = confusion_matrix(y_pred=[np.argmax(x) for x in y_predict], y_true=[np.argmax(x) for x in classes_batch])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot()
plt.title('Confusion matrix of the weather recognition')
plt.xticks(rotation=45)
plt.savefig('cm_weather_CNN.png')
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step

# %%
#This function will display a number of random images as well as the predictions for the type of weather.

def predict_one(model, num_images = None):  
    image_batch, classes_batch = next(test_generator)
    predicted_batch = model.predict(image_batch)
    for k in range(0,image_batch.shape[0] if num_images is None else num_images):
        image = image_batch[k]
        real_class = class_names[np.argmax(classes_batch[k])]
        predicted_class = class_names[np.argmax(predicted_batch[k])]
        value_predicted = predicted_batch[k]
        isTrue = (real_class == predicted_class)
        plt.figure(k)
        plt.title(str("Correct Prediction" if isTrue else "Incorrect Prediction") + ' - class: ' + real_class + ' - ' + 'predicted: ' + predicted_class + str(value_predicted))
        plt.axis('off')
        plt.savefig('./' + real_class + '_' + predicted_class + '_' + str(value_predicted) + '.png')
        plt.imshow(image)

# %%
predict_one(model, 5) #<--you can show multiple pictures with this command. Just fill in the number you want to see.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
